# %%
from pyaxidraw import axidraw
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8ac58503a0c8> in <module>
# ----> 1 from pyaxidraw import axidraw
#
# ModuleNotFoundError: No module named 'pyaxidraw'

# %%
ad = axidraw.AxiDraw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d3a9a30e2f6c> in <module>
# ----> 1 ad = axidraw.AxiDraw()
#
# NameError: name 'axidraw' is not defined

# %%
ad.plot_setup("my_super_cool_art_rescaled.svg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d5ccf8525f81> in <module>
# ----> 1 ad.plot_setup("my_super_cool_art_rescaled.svg")
#
# NameError: name 'ad' is not defined

# %%
calibrate = False

if calibrate:
    ad.interactive()
    ad.connect() 
else:
    ad.plot_run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d9ec996d7477> in <module>
#       5     ad.connect()
#       6 else:
# ----> 7     ad.plot_run()
#
# NameError: name 'ad' is not defined

# %%
if calibrate:
    ad.pendown()

# %%
if calibrate:
    ad.penup()
